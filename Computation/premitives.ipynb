# %% [markdown]
# import random
# rand = random.randint(9,251)
# print(rand)

# %%
import random
rand = random.randint(1, 100)
print(f"Random integer between 1 and 100: {rand}")
# Out:
# Random integer between 1 and 100: 27

# %%
pi = 3.14159
radius = 2.2
area = pi * (radius ** 2)
radius = radius + 1
print(f"Area of circle with radius {radius}: {area}")
# Out:
# Area of circle with radius 3.2: 15.205295600000001

# %%
name = input("Enter your name: ")
score = float(input("Enter your score: "))
pass_mark = 50

if score >= pass_mark:
    print(f"Congratulations {name}, you have passed!")
else:
    print(f"Sorry {name}, you have failed. Better luck next time!")
# Out:
# Congratulations Enoch, you have passed!

# %%
type[5]
print(3.0-1)
